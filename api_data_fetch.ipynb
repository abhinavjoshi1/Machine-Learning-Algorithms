# %% [markdown]
# Fetching data from an API

# %% [markdown]
# Import Libs

# %%
import pandas as pd
import requests
import json
import pprint
from pandas import json_normalize

# %%
import http.client

conn = http.client.HTTPSConnection("odds.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "7233367db9msh2b416971d4899e6p17d9fdjsnf357ee9b7fe4",
    'x-rapidapi-host': "odds.p.rapidapi.com"
}

conn.request("GET", "/v4/sports/upcoming/odds?regions=us&oddsFormat=decimal&markets=h2h%2Cspreads&dateFormat=iso", headers=headers)

res = conn.getresponse()

data = res.read().decode("utf-8")

json_data = json.loads(data)

pprint.pp(json_data)
# Out:
# [{'id': '8a3d2a20bff2f936ea4126fa2b45a577',
#   'sport_key': 'basketball_nbl',
#   'sport_title': 'NBL',
#   'commence_time': '2025-12-04T08:36:00Z',
#   'home_team': 'Illawarra Hawks',
#   'away_team': 'S.E. Melbourne Phoenix',
#   'bookmakers': [{'key': 'betrivers',
#                   'title': 'BetRivers',
#                   'last_update': '2025-12-04T07:19:11Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:19:11Z',
#                                'outcomes': [{'name': 'Illawarra Hawks',
#                                              'price': 1.85},
#                                             {'name': 'S.E. Melbourne Phoenix',
#                                              'price': 1.93}]},
#                               {'key': 'spreads',
#                                'last_update': '2025-12-04T07:19:11Z',
#                                'outcomes': [{'name': 'Illawarra Hawks',
#                                              'price': 1.85,
#                                              'point': -0.5},
#                                             {'name': 'S.E. Melbourne Phoenix',
#                                              'price': 1.93,
#                                              'point': 0.5}]}]}]},
#  {'id': 'e6345978f49affac3c1568bad3869e23',
#   'sport_key': 'cricket_international_t20',
#   'sport_title': 'International Twenty20',
#   'commence_time': '2025-12-04T09:00:00Z',
#   'home_team': 'Nigeria',
#   'away_team': 'Zambia',
#   'bookmakers': [{'key': 'fanduel',
#                   'title': 'FanDuel',
#                   'last_update': '2025-12-04T07:19:10Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:19:10Z',
#                                'outcomes': [{'name': 'Nigeria', 'price': 1.24},
#                                             {'name': 'Zambia',
#                                              'price': 3.9}]}]},
#                  {'key': 'bovada',
#                   'title': 'Bovada',
#                   'last_update': '2025-12-04T07:19:23Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:19:23Z',
#                                'outcomes': [{'name': 'Nigeria', 'price': 1.25},
#                                             {'name': 'Zambia',
#                                              'price': 3.75}]}]},
#                  {'key': 'betonlineag',
#                   'title': 'BetOnline.ag',
#                   'last_update': '2025-12-04T07:19:14Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:19:14Z',
#                                'outcomes': [{'name': 'Nigeria', 'price': 1.29},
#                                             {'name': 'Zambia',
#                                              'price': 3.54}]}]}]},
#  {'id': '70459ef32806b951f2e8da1ec1e86174',
#   'sport_key': 'basketball_nbl',
#   'sport_title': 'NBL',
#   'commence_time': '2025-12-04T10:36:00Z',
#   'home_team': 'Perth Wildcats',
#   'away_team': 'Melbourne United',
#   'bookmakers': [{'key': 'betrivers',
#                   'title': 'BetRivers',
#                   'last_update': '2025-12-04T07:19:11Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:19:11Z',
#                                'outcomes': [{'name': 'Melbourne United',
#                                              'price': 1.7},
#                                             {'name': 'Perth Wildcats',
#                                              'price': 2.14}]},
#                               {'key': 'spreads',
#                                'last_update': '2025-12-04T07:19:11Z',
#                                'outcomes': [{'name': 'Melbourne United',
#                                              'price': 1.88,
#                                              'point': -2.5},
#                                             {'name': 'Perth Wildcats',
#                                              'price': 1.88,
#                                              'point': 2.5}]}]}]},
#  {'id': 'fc1c6f1b9a52bdd3a775463b680af47c',
#   'sport_key': 'boxing_boxing',
#   'sport_title': 'Boxing',
#   'commence_time': '2025-12-04T11:00:00Z',
#   'home_team': 'Thammanoon Niyomtrong',
#   'away_team': 'Junior Zarate',
#   'bookmakers': [{'key': 'betus',
#                   'title': 'BetUS',
#                   'last_update': '2025-12-04T07:18:17Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:18:17Z',
#                                'outcomes': [{'name': 'Junior Zarate',
#                                              'price': 3.2},
#                                             {'name': 'Thammanoon Niyomtrong',
#                                              'price': 1.36}]}]},
#                  {'key': 'fanduel',
#                   'title': 'FanDuel',
#                   'last_update': '2025-12-04T07:18:04Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:18:04Z',
#                                'outcomes': [{'name': 'Junior Zarate',
#                                              'price': 2.88},
#                                             {'name': 'Thammanoon Niyomtrong',
#                                              'price': 1.38}]}]},
#                  {'key': 'betonlineag',
#                   'title': 'BetOnline.ag',
#                   'last_update': '2025-12-04T07:17:22Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:17:22Z',
#                                'outcomes': [{'name': 'Junior Zarate',
#                                              'price': 3.02},
#                                             {'name': 'Thammanoon Niyomtrong',
#                                              'price': 1.37}]}]},
#                  {'key': 'lowvig',
#                   'title': 'LowVig.ag',
#                   'last_update': '2025-12-04T07:17:08Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:17:08Z',
#                                'outcomes': [{'name': 'Junior Zarate',
#                                              'price': 3.02},
#                                             {'name': 'Thammanoon Niyomtrong',
#                                              'price': 1.37}]}]},
#                  {'key': 'bovada',
#                   'title': 'Bovada',
#                   'last_update': '2025-12-04T07:18:57Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:18:57Z',
#                                'outcomes': [{'name': 'Junior Zarate',
#                                              'price': 3.0},
#                                             {'name': 'Thammanoon Niyomtrong',
#                                              'price': 1.36}]}]},
#                  {'key': 'draftkings',
#                   'title': 'DraftKings',
#                   'last_update': '2025-12-04T07:18:30Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:18:29Z',
#                                'outcomes': [{'name': 'Junior Zarate',
#                                              'price': 3.2},
#                                             {'name': 'Thammanoon Niyomtrong',
#                                              'price': 1.35}]}]}]},
#  {'id': '3a3a378a28557429db0d6f4540a3a68e',
#   'sport_key': 'cricket_international_t20',
#   'sport_title': 'International Twenty20',
#   'commence_time': '2025-12-04T13:00:00Z',
#   'home_team': 'Sierra Leone',
#   'away_team': 'Rwanda',
#   'bookmakers': [{'key': 'fanduel',
#                   'title': 'FanDuel',
#                   'last_update': '2025-12-04T07:19:10Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:19:10Z',
#                                'outcomes': [{'name': 'Rwanda', 'price': 1.31},
#                                             {'name': 'Sierra Leone',
#                                              'price': 3.25}]}]},
#                  {'key': 'bovada',
#                   'title': 'Bovada',
#                   'last_update': '2025-12-04T07:19:23Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:19:23Z',
#                                'outcomes': [{'name': 'Rwanda', 'price': 1.33},
#                                             {'name': 'Sierra Leone',
#                                              'price': 3.2}]}]},
#                  {'key': 'betonlineag',
#                   'title': 'BetOnline.ag',
#                   'last_update': '2025-12-04T07:19:14Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:19:14Z',
#                                'outcomes': [{'name': 'Rwanda', 'price': 1.36},
#                                             {'name': 'Sierra Leone',
#                                              'price': 3.23}]}]}]},
#  {'id': 'c5885daa9feb5652f6d07e5871299f22',
#   'sport_key': 'soccer_poland_ekstraklasa',
#   'sport_title': 'Ekstraklasa - Poland',
#   'commence_time': '2025-12-04T16:00:00Z',
#   'home_team': 'Wisła Płock',
#   'away_team': 'Cracovia Kraków',
#   'bookmakers': [{'key': 'betrivers',
#                   'title': 'BetRivers',
#                   'last_update': '2025-12-04T07:19:22Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:19:22Z',
#                                'outcomes': [{'name': 'Cracovia Kraków',
#                                              'price': 2.65},
#                                             {'name': 'Wisła Płock',
#                                              'price': 2.65},
#                                             {'name': 'Draw', 'price': 3.05}]}]},
#                  {'key': 'fanduel',
#                   'title': 'FanDuel',
#                   'last_update': '2025-12-04T07:17:21Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:17:21Z',
#                                'outcomes': [{'name': 'Cracovia Kraków',
#                                              'price': 2.6},
#                                             {'name': 'Wisła Płock',
#                                              'price': 2.8},
#                                             {'name': 'Draw', 'price': 3.1}]}]},
#                  {'key': 'betmgm',
#                   'title': 'BetMGM',
#                   'last_update': '2025-12-04T07:19:23Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:19:23Z',
#                                'outcomes': [{'name': 'Cracovia Kraków',
#                                              'price': 2.6},
#                                             {'name': 'Wisła Płock',
#                                              'price': 2.75},
#                                             {'name': 'Draw', 'price': 3.1}]}]},
#                  {'key': 'fanatics',
#                   'title': 'Fanatics',
#                   'last_update': '2025-12-04T07:18:15Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:18:15Z',
#                                'outcomes': [{'name': 'Cracovia Kraków',
#                                              'price': 2.6},
#                                             {'name': 'Wisła Płock',
#                                              'price': 2.75},
#                                             {'name': 'Draw', 'price': 3.0}]}]},
#                  {'key': 'draftkings',
#                   'title': 'DraftKings',
#                   'last_update': '2025-12-04T07:19:09Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:19:09Z',
#                                'outcomes': [{'name': 'Cracovia Kraków',
#                                              'price': 2.6},
#                                             {'name': 'Wisła Płock',
#                                              'price': 2.85},
#                                             {'name': 'Draw', 'price': 3.05}]}]},
#                  {'key': 'bovada',
#                   'title': 'Bovada',
#                   'last_update': '2025-12-04T07:19:13Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:19:13Z',
#                                'outcomes': [{'name': 'Cracovia Kraków',
#                                              'price': 2.64},
#                                             {'name': 'Wisła Płock',
#                                              'price': 2.8},
#                                             {'name': 'Draw', 'price': 2.88}]},
#                               {'key': 'spreads',
#                                'last_update': '2025-12-04T07:19:13Z',
#                                'outcomes': [{'name': 'Cracovia Kraków',
#                                              'price': 1.85,
#                                              'point': 0.0},
#                                             {'name': 'Wisła Płock',
#                                              'price': 1.98,
#                                              'point': 0.0}]}]},
#                  {'key': 'lowvig',
#                   'title': 'LowVig.ag',
#                   'last_update': '2025-12-04T07:19:22Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:19:22Z',
#                                'outcomes': [{'name': 'Cracovia Kraków',
#                                              'price': 2.58},
#                                             {'name': 'Wisła Płock',
#                                              'price': 2.8},
#                                             {'name': 'Draw', 'price': 2.98}]},
#                               {'key': 'spreads',
#                                'last_update': '2025-12-04T07:19:22Z',
#                                'outcomes': [{'name': 'Cracovia Kraków',
#                                              'price': 1.85,
#                                              'point': 0.0},
#                                             {'name': 'Wisła Płock',
#                                              'price': 1.98,
#                                              'point': 0.0}]}]},
#                  {'key': 'betonlineag',
#                   'title': 'BetOnline.ag',
#                   'last_update': '2025-12-04T07:18:15Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:18:15Z',
#                                'outcomes': [{'name': 'Cracovia Kraków',
#                                              'price': 2.58},
#                                             {'name': 'Wisła Płock',
#                                              'price': 2.8},
#                                             {'name': 'Draw', 'price': 2.98}]},
#                               {'key': 'spreads',
#                                'last_update': '2025-12-04T07:18:15Z',
#                                'outcomes': [{'name': 'Cracovia Kraków',
#                                              'price': 1.85,
#                                              'point': 0.0},
#                                             {'name': 'Wisła Płock',
#                                              'price': 1.98,
#                                              'point': 0.0}]}]},
#                  {'key': 'betus',
#                   'title': 'BetUS',
#                   'last_update': '2025-12-04T07:18:29Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:18:29Z',
#                                'outcomes': [{'name': 'Cracovia Kraków',
#                                              'price': 2.58},
#                                             {'name': 'Wisła Płock',
#                                              'price': 2.88},
#                                             {'name': 'Draw', 'price': 2.85}]},
#                               {'key': 'spreads',
#                                'last_update': '2025-12-04T07:18:29Z',
#                                'outcomes': [{'name': 'Cracovia Kraków',
#                                              'price': 1.82,
#                                              'point': 0.0},
#                                             {'name': 'Wisła Płock',
#                                              'price': 1.93,
#                                              'point': 0.0}]}]}]},
#  {'id': '0f9e976bb34fe6a5937e72f2af775a32',
#   'sport_key': 'icehockey_liiga',
#   'sport_title': 'Liiga',
#   'commence_time': '2025-12-04T16:30:00Z',
#   'home_team': 'Ilves',
#   'away_team': 'HPK',
#   'bookmakers': [{'key': 'bovada',
#                   'title': 'Bovada',
#                   'last_update': '2025-12-04T07:19:03Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:19:03Z',
#                                'outcomes': [{'name': 'HPK', 'price': 2.5},
#                                             {'name': 'Ilves', 'price': 1.5}]},
#                               {'key': 'spreads',
#                                'last_update': '2025-12-04T07:19:03Z',
#                                'outcomes': [{'name': 'HPK',
#                                              'price': 1.54,
#                                              'point': 1.5},
#                                             {'name': 'Ilves',
#                                              'price': 2.4,
#                                              'point': -1.5}]}]},
#                  {'key': 'draftkings',
#                   'title': 'DraftKings',
#                   'last_update': '2025-12-04T07:18:45Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:18:45Z',
#                                'outcomes': [{'name': 'HPK', 'price': 2.4},
#                                             {'name': 'Ilves', 'price': 1.57}]},
#                               {'key': 'spreads',
#                                'last_update': '2025-12-04T07:18:45Z',
#                                'outcomes': [{'name': 'HPK',
#                                              'price': 1.52,
#                                              'point': 1.5},
#                                             {'name': 'Ilves',
#                                              'price': 2.6,
#                                              'point': -1.5}]}]},
#                  {'key': 'betrivers',
#                   'title': 'BetRivers',
#                   'last_update': '2025-12-04T07:18:32Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:18:32Z',
#                                'outcomes': [{'name': 'HPK', 'price': 2.65},
#                                             {'name': 'Ilves', 'price': 1.53}]},
#                               {'key': 'spreads',
#                                'last_update': '2025-12-04T07:18:32Z',
#                                'outcomes': [{'name': 'HPK',
#                                              'price': 1.56,
#                                              'point': 1.5},
#                                             {'name': 'Ilves',
#                                              'price': 2.5,
#                                              'point': -1.5}]}]}]},
#  {'id': '3d403f8ccadd5089e61c5a2ad0887d0b',
#   'sport_key': 'icehockey_mestis',
#   'sport_title': 'Mestis',
#   'commence_time': '2025-12-04T16:30:00Z',
#   'home_team': 'Hermes',
#   'away_team': 'JoKP',
#   'bookmakers': [{'key': 'bovada',
#                   'title': 'Bovada',
#                   'last_update': '2025-12-04T07:19:16Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:19:16Z',
#                                'outcomes': [{'name': 'Hermes', 'price': 2.65},
#                                             {'name': 'JoKP', 'price': 1.45}]},
#                               {'key': 'spreads',
#                                'last_update': '2025-12-04T07:19:16Z',
#                                'outcomes': [{'name': 'Hermes',
#                                              'price': 1.65,
#                                              'point': 1.5},
#                                             {'name': 'JoKP',
#                                              'price': 2.2,
#                                              'point': -1.5}]}]},
#                  {'key': 'betrivers',
#                   'title': 'BetRivers',
#                   'last_update': '2025-12-04T07:18:45Z',
#                   'markets': [{'key': 'h2h',
#                                'last_update': '2025-12-04T07:18:45Z',
#                                'outcomes': [{'name': 'Hermes', 'price': 2.65},
#                                             {'name': 'JoKP', 'price': 1.43}]},
#                               {'key': 'spreads',
#                                'last_update': '2025-12-04T07:18:45Z',
#                                'outcomes': [{'name': 'Hermes',
#                                              'price': 1.61,
#                                              'point': 1.5},
#                                             {'name': 'JoKP',
#                                              'price': 2.2,
#                                              'point': -1.5}]}]}]}]

# %% [markdown]
# Conversion to Dataframe

# %%
df = json_normalize(
    json_data,
    record_path=['bookmakers', 'markets', 'outcomes'],
    meta=[
        'id',
        'sport_key',
        'sport_title',
        'commence_time',
        'home_team',
        'away_team',
        ['bookmakers', 'key'],
        ['bookmakers', 'title'],
        ['bookmakers', 'last_update'],
        ['bookmakers', 'markets', 'key']
    ],
    errors='ignore'
)
print(df)
# Out:
#                       name  price  point                                id  \
# 0          Illawarra Hawks   1.85    NaN  8a3d2a20bff2f936ea4126fa2b45a577
# 1   S.E. Melbourne Phoenix   1.93    NaN  8a3d2a20bff2f936ea4126fa2b45a577
# 2          Illawarra Hawks   1.85   -0.5  8a3d2a20bff2f936ea4126fa2b45a577
# 3   S.E. Melbourne Phoenix   1.93    0.5  8a3d2a20bff2f936ea4126fa2b45a577
# 4                  Nigeria   1.24    NaN  e6345978f49affac3c1568bad3869e23
# ..                     ...    ...    ...                               ...
# 82                    JoKP   2.20   -1.5  3d403f8ccadd5089e61c5a2ad0887d0b
# 83                  Hermes   2.65    NaN  3d403f8ccadd5089e61c5a2ad0887d0b
# 84                    JoKP   1.43    NaN  3d403f8ccadd5089e61c5a2ad0887d0b
# 85                  Hermes   1.61    1.5  3d403f8ccadd5089e61c5a2ad0887d0b
# 86                    JoKP   2.20   -1.5  3d403f8ccadd5089e61c5a2ad0887d0b
#
#                     sport_key             sport_title         commence_time  \
# 0              basketball_nbl                     NBL  2025-12-04T08:36:00Z
# 1              basketball_nbl                     NBL  2025-12-04T08:36:00Z
# 2              basketball_nbl                     NBL  2025-12-04T08:36:00Z
# 3              basketball_nbl                     NBL  2025-12-04T08:36:00Z
# 4   cricket_international_t20  International Twenty20  2025-12-04T09:00:00Z
# ..                        ...                     ...                   ...
# 82           icehockey_mestis                  Mestis  2025-12-04T16:30:00Z
# 83           icehockey_mestis                  Mestis  2025-12-04T16:30:00Z
# 84           icehockey_mestis                  Mestis  2025-12-04T16:30:00Z
# 85           icehockey_mestis                  Mestis  2025-12-04T16:30:00Z
# 86           icehockey_mestis                  Mestis  2025-12-04T16:30:00Z
#
#           home_team               away_team bookmakers.key bookmakers.title  \
# 0   Illawarra Hawks  S.E. Melbourne Phoenix      betrivers        BetRivers
# 1   Illawarra Hawks  S.E. Melbourne Phoenix      betrivers        BetRivers
# 2   Illawarra Hawks  S.E. Melbourne Phoenix      betrivers        BetRivers
# 3   Illawarra Hawks  S.E. Melbourne Phoenix      betrivers        BetRivers
# 4           Nigeria                  Zambia        fanduel          FanDuel
# ..              ...                     ...            ...              ...
# 82           Hermes                    JoKP         bovada           Bovada
# 83           Hermes                    JoKP      betrivers        BetRivers
# 84           Hermes                    JoKP      betrivers        BetRivers
# 85           Hermes                    JoKP      betrivers        BetRivers
# 86           Hermes                    JoKP      betrivers        BetRivers
#
#    bookmakers.last_update bookmakers.markets.key
# 0    2025-12-04T07:19:11Z                    h2h
# 1    2025-12-04T07:19:11Z                    h2h
# 2    2025-12-04T07:19:11Z                spreads
# 3    2025-12-04T07:19:11Z                spreads
# 4    2025-12-04T07:19:10Z                    h2h
# ..                    ...                    ...
# 82   2025-12-04T07:19:16Z                spreads
# 83   2025-12-04T07:18:45Z                    h2h
# 84   2025-12-04T07:18:45Z                    h2h
# 85   2025-12-04T07:18:45Z                spreads
# 86   2025-12-04T07:18:45Z                spreads
#
# [87 rows x 13 columns]
